# %%
import pickle

s = open("Marie_Gold_resnet50_features.pkl","rb")
features = pickle.load(s)

# %%
features
# Out:
# {'Growth_Level_100% (1)': array([[0.03281399, 0.06364062, 2.3193734 , ..., 1.1893226 , 0.15890734,
#          0.        ]], dtype=float32),
#  'Growth_Level_100% (10)': array([[0.07809813, 0.01437728, 2.3017478 , ..., 1.0496184 , 0.04566933,
#          0.        ]], dtype=float32),
#  'Growth_Level_100% (100)': array([[0.        , 0.08566881, 2.6463888 , ..., 2.2790148 , 0.00422315,
#          0.        ]], dtype=float32),
#  'Growth_Level_100% (101)': array([[0.08078468, 0.03692079, 2.8457265 , ..., 2.6314323 , 0.04094396,
#          0.        ]], dtype=float32),
#  'Growth_Level_100% (11)': array([[0.09528582, 0.06712721, 2.8561532 , ..., 1.0709512 , 0.01536464,
#          0.        ]], dtype=float32),
#  'Growth_Level_100% (12)': array([[0.01745872, 0.15136912, 2.8559308 , ..., 1.0082291 , 0.01204478,
#          0.        ]], dtype=float32),
#  'Growth_Level_100% (13)': array([[0.13408595, 0.02144098, 2.8926094 , ..., 1.300814  , 0.02366045,
# ...

# %%
label = {}

# %%
def get_class(ipt):
    class_id = 0
    if 'Growth_Level_25%' in ipt : 
        class_id = "Growth_Level_25%"
   
   
    elif 'Growth_Level_50%' in ipt:
        class_id = "Growth_Level_50%"

    elif 'Growth_Level_75%' in ipt:
        class_id = "Growth_Level_75%"
    else :
      class_id = "Growth_Level_100%"

    
    return class_id

# %%
for key, value in features.items() :
    label[key] = get_class(key)

# %%
get_class('Growth_Level_100% (33)')
# Out:
# 'Growth_Level_100%'

# %%
x = []
y = []

# %%
for key, value in features.items() :
    x.append(features[key][0])
    y.append(label[key])

# %%
x[1].shape
# Out:
# (2048,)

# %%
label['Growth_Level_100% (33)']
# Out:
# 'Growth_Level_100%'

# %%
print (type(x))
print (type(y))
# Out:
# <class 'list'>
# <class 'list'>

# %%
import numpy as np
x=np.array(x)
y=np.array(y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=.4,
                                                    random_state=0)

# %%
#svm classifier

from sklearn.model_selection import cross_val_score
from sklearn import svm
clf = svm.SVC(kernel='linear')
scoresvm = cross_val_score(clf, x, y, cv=4)
scoresvm
print("Accuracy: %0.2f (+/- %0.2f)" % (scoresvm.mean(), scoresvm.std() * 2))
# Out:
# Accuracy: 1.00 (+/- 0.00)

# %%
#KNN classifier

from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
clfknn = KNeighborsClassifier(n_neighbors=10)
scores = cross_val_score(clfknn, x, y, cv=4)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# Accuracy: 0.97 (+/- 0.03)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier

clf = KNeighborsClassifier(n_neighbors=10)

#Train the model using the training sets
clf=clf.fit(X_train, y_train)

# %%
import pickle
from pickle import dump
dump(clf, open('Marie_Gold.pkl', 'wb'))
s = open("Marie_Gold.pkl","rb")
clf2 = pickle.load(s)

# %%
clf2.predict(X_test)
# Out:
# array(['Growth_Level_75%', 'Growth_Level_75%', 'Growth_Level_50%',
#        'Growth_Level_75%', 'Growth_Level_25%', 'Growth_Level_50%',
#        'Growth_Level_75%', 'Growth_Level_100%', 'Growth_Level_25%',
#        'Growth_Level_100%', 'Growth_Level_75%', 'Growth_Level_100%',
#        'Growth_Level_50%', 'Growth_Level_100%', 'Growth_Level_25%',
#        'Growth_Level_75%', 'Growth_Level_25%', 'Growth_Level_75%',
#        'Growth_Level_50%', 'Growth_Level_100%', 'Growth_Level_50%',
#        'Growth_Level_75%', 'Growth_Level_75%', 'Growth_Level_50%',
#        'Growth_Level_25%', 'Growth_Level_100%', 'Growth_Level_75%',
#        'Growth_Level_50%', 'Growth_Level_75%', 'Growth_Level_100%',
#        'Growth_Level_50%', 'Growth_Level_25%', 'Growth_Level_25%',
#        'Growth_Level_75%', 'Growth_Level_50%', 'Growth_Level_100%',
#        'Growth_Level_100%', 'Growth_Level_50%', 'Growth_Level_25%',
#        'Growth_Level_100%', 'Growth_Level_50%', 'Growth_Level_75%',
# ...
